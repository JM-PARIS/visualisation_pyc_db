# %% [markdown]
# Connected to env_geopandas (Python 3.13.7)

# %%
#!/usr/bin/env python
# -*- encoding: utf-8 -*-
'''
@FILE :Untitled-1
@Description :
@ :2026/02/04 16:13:03
@Author : JM PARIS
'''


###LIBRARIES
###


#import fichier
df = pd.read_csv("all_coordinates.csv") #_new
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#       3 '''
#       4 @FILE :Untitled-1
#       5 @Description :
#       6 @ :2026/02/04 16:13:03
#       7 @Author : JM PARIS
#       8 '''
#      11 ###LIBRARIES
#      12 ###
#      13
#      14
#      15 #import fichier
# ---> 16 df = pd.read_csv("all_coordinates.csv") #_new
#      17 df.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
#import fichier
df = pd.read_csv("all_coordinates.csv") #_new
df.head()
# Out:
#        lat3      long3     PyC100 climate
# 0  38.95342 -119.92740  30.350133       C
# 1  38.95342 -119.92740  37.284895       C
# 2  38.95342 -119.92740  39.896358       C
# 3  38.95342 -119.92740  42.923639       C
# 4  38.95367 -119.92782  34.930532       C
